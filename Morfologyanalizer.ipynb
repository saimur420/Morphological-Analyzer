# %%
! pip install --only-binary :all: pynini
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 161.1 MB 3.4 kB/s
# ...

# %%
import pynini

# %%
pynini.union("foo", "bar", "baz").optimize()
# Out:
# <vector Fst at 0x7f6e8664a670>
